# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
cardio = pd.read_csv('Maladie_Cardio.csv')

# %%
cardio.shape
# Out:
# (303, 14)

# %%
cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   age      303 non-null    int64
#  1   genre    303 non-null    int64
#  2   td       303 non-null    int64
#  3   psr      303 non-null    int64
#  4   chol     303 non-null    int64
#  5   gaj      303 non-null    int64
#  6   ecgr     303 non-null    int64
#  7   fcm      303 non-null    int64
#  8   effang   303 non-null    int64
#  9   dinde    303 non-null    float64
#  10  penteff  303 non-null    int64
#  11  nvc      303 non-null    int64
#  12  rshal    303 non-null    int64
#  13  target   303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
cardio.describe()
# Out:
#               age       genre          td         psr        chol         gaj  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#              ecgr         fcm      effang       dinde     penteff         nvc  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
cardio.head()
# Out:
#    age  genre  td  psr  chol  gaj  ecgr  fcm  effang  dinde  penteff  nvc  \
# 0   63      1   3  145   233    1     0  150       0    2.3        0    0
# 1   37      1   2  130   250    0     1  187       0    3.5        0    0
# 2   41      0   1  130   204    0     0  172       0    1.4        2    0
# 3   56      1   1  120   236    0     1  178       0    0.8        2    0
# 4   57      0   0  120   354    0     1  163       1    0.6        2    0
#
#    rshal  target
# 0      1       1
# 1      2       1
# 2      2       1
# 3      2       1
# 4      2       1

# %%
cardio.tail()
# Out:
#      age  genre  td  psr  chol  gaj  ecgr  fcm  effang  dinde  penteff  nvc  \
# 298   57      0   0  140   241    0     1  123       1    0.2        1    0
# 299   45      1   3  110   264    0     1  132       0    1.2        1    0
# 300   68      1   0  144   193    1     1  141       0    3.4        1    2
# 301   57      1   0  130   131    0     1  115       1    1.2        1    1
# 302   57      0   1  130   236    0     0  174       0    0.0        1    1
#
#      rshal  target
# 298      3       0
# 299      3       0
# 300      3       0
# 301      3       0
# 302      2       0

# %%
cardio["age"].plot.hist(bins=50)
plt.title("La Distibution d'Age")
plt.xlabel("Age")
plt.ylabel("Fréquence")
# Out:
# Text(0, 0.5, 'Fréquence')

# %%
sns.distplot(cardio['age'])
plt.title("La Distibution d'Age")
plt.xlabel("Age")
plt.ylabel("Densité")
plt.show
# Out:
# D:\Programmes\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#La fréquence de chaque valeur de la variable target
T=cardio['target']
sns.countplot(T)
plt.title("La fréquence de chaque valeur de la variable target")
plt.xlabel("Sain                                             Malade")
plt.ylabel("Fréquence")
# Out:
# D:\Programmes\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Fréquence')

# %%
#La variable target en fonction du type de la douleur thoracique
sns.barplot(cardio["td"], T)
plt.title("Maladie Cradiovasculaire en fonction du type de la douleur")
plt.xlabel("Type de la douleur thoracique")
plt.ylabel("Target")
# Out:
# D:\Programmes\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Target')

# %%
cardio.plot.hist(figsize=(10,30), subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %%
#Appliquer les analyses sur les individus agés plus de 50 ans
plus_50=cardio[cardio['age'] > 50]
plus_50
# Out:
#      age  genre  td  psr  chol  gaj  ecgr  fcm  effang  dinde  penteff  nvc  \
# 0     63      1   3  145   233    1     0  150       0    2.3        0    0
# 3     56      1   1  120   236    0     1  178       0    0.8        2    0
# 4     57      0   0  120   354    0     1  163       1    0.6        2    0
# 5     57      1   0  140   192    0     1  148       0    0.4        1    0
# 6     56      0   1  140   294    0     0  153       0    1.3        1    0
# ..   ...    ...  ..  ...   ...  ...   ...  ...     ...    ...      ...  ...
# 297   59      1   0  164   176    1     0   90       0    1.0        1    2
# 298   57      0   0  140   241    0     1  123       1    0.2        1    0
# 300   68      1   0  144   193    1     1  141       0    3.4        1    2
# 301   57      1   0  130   131    0     1  115       1    1.2        1    1
# 302   57      0   1  130   236    0     0  174       0    0.0        1    1
#
#      rshal  target
# 0        1       1
# ...

# %%
# Axes 0, 0 (ligne 0, colonne 0)
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(plus_50["age"], 
                      plus_50["chol"], 
                      c=plus_50["target"],
                      cmap='winter')
ax0.set(title="Maladie Cardiovasculaire en fonction des Niveaux du Cholesterole",
        ylabel="Cholesterole")

# Définir l'axe des X
ax0.set_xlim([50, 80])

# Définir la ligne de la moyenne
ax0.axhline(y=plus_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axes 1, 1 (ligne 1, colonne 1)
scatter = ax1.scatter(plus_50["age"], 
                      plus_50["fcm"], 
                      c=plus_50["target"],
                      cmap='winter')
ax1.set(title="Maladie Cardiovasculaire en fonction de la Fréquence Cardiaque Maximale",
        xlabel="Age",
        ylabel="Fréquence Cardiaque Maximale")

# Set the y axis
ax1.set_ylim([60, 200])

# Setup a mean line
ax1.axhline(y=plus_50["fcm"].mean(),
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Analyse des Maladies Cardiovasculaires', fontsize=16, fontweight='bold');

# %%
#Distibution de la fréquence cardiaque maximale
sns.distplot(cardio['fcm'])
plt.title("La Distibution de la Fréquence Cardiaque Maximale")
plt.xlabel("Fréquence Cardiaque Maximale")
plt.ylabel("Densité")
# Out:
# D:\Programmes\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Densité')

# %%
Jeune = cardio[(cardio.age>=29)&(cardio.age<40)]
Moyen = cardio[(cardio.age>=40)&(cardio.age<55)]
Agé = cardio[(cardio.age>55)]

# %%
print("Jeune:",len(Jeune))
print("Moyen:",len(Moyen)) 
print("Agé",len(Agé))
# Out:
# Jeune: 16
# Moyen: 128
# Agé 151

# %%
sns.barplot(x = ["Jeune","Moyen","Agé"], y =[len(Jeune),len(Moyen),len(Agé)], color = "lightblue")
plt.title("Intervales d'Age")

plt.ylabel("Fréquence")
# Out:
# Text(0, 0.5, 'Fréquence')

# %%
fig, axes = plt.subplots( nrows=5, ncols=3, figsize=(15,40) )
plt.subplots_adjust( wspace=0.20, hspace=0.20, top=0.97 )
plt.suptitle("Maldie Cardiovasculaire", fontsize=20)

axes[0,0].hist(cardio.age)
axes[0,0].set_xlabel("Age")
axes[0,0].set_ylabel("Nombre des Patients")

axes[0,1].hist(cardio.genre)
axes[0,1].set_xlabel("Genre (male = 1,female = 0)")
axes[0,1].set_ylabel("Nombre des Patients")

axes[0,2].hist(cardio.td)
axes[0,2].set_xlabel("Type de la douleur thoracique")
axes[0,2].set_ylabel("Nombre des Patients")

axes[1,0].hist(cardio.psr)
axes[1,0].set_xlabel("Pression sanguine au repos")
axes[1,0].set_ylabel("Nombre des Patients")

axes[1,1].hist(cardio.chol)
axes[1,1].set_xlabel("Cholestérol")
axes[1,1].set_ylabel("Nombre des Patients")


axes[1,2].hist(cardio.gaj)
axes[1,2].set_xlabel("Glycémie à jeun")
axes[1,2].set_ylabel("Nombre des Patients")


axes[2,0].hist(cardio.ecgr)
axes[2,0].set_xlabel("Résultats de l’électrocardiogramme de repos ")
axes[2,0].set_ylabel("Nombre des Patients")

axes[2,1].hist(cardio.fcm)
axes[2,1].set_xlabel("Fréquence cardiaque maximale")
axes[2,1].set_ylabel("Nombre des Patients")

axes[2,2].hist(cardio.effang)
axes[2,2].set_xlabel("Angine de poitrine provoquée par l'effort (1 = yes, 0 = no)")
axes[2,2].set_ylabel("exang(Number of Patients)")

axes[3,0].hist(cardio.dinde)
axes[3,0].set_xlabel("Dépression ST induite par l'effort par rapport à celle au repos")
axes[3,0].set_ylabel("Nombre des Patients")

axes[3,1].hist(cardio.penteff)
axes[3,1].set_xlabel("La pente du segment ST de l'effort de pointe")
axes[3,1].set_ylabel("Nombre des Patients")

axes[3,2].hist(cardio.nvc)
axes[3,2].set_xlabel("Nombre de grands vaisseaux (0-3) colorés par fluoroscopie")
axes[3,2].set_ylabel("Nombre des Patients")

axes[4,0].hist(cardio.rshal)
axes[4,0].set_xlabel("Résultat du stress au thallium")
axes[4,0].set_ylabel("Nombre des Patients")

axes[4,1].hist(cardio.target)
axes[4,2].axis("off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
corr = cardio.corr()
corr
# Out:
#               age     genre        td       psr      chol       gaj      ecgr  \
# age      1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308 -0.116211
# genre   -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032 -0.058196
# td      -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444  0.044421
# psr      0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531 -0.114103
# chol     0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294 -0.151040
# gaj      0.121308  0.045032  0.094444  0.177531  0.013294  1.000000 -0.084189
# ecgr    -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189  1.000000
# fcm     -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567  0.044123
# effang   0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665 -0.070733
# dinde    0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747 -0.058770
# penteff -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894  0.093045
# ...

# %%
plt.figure(figsize =(20,15))
sns.heatmap(corr,annot= True)
# Out:
# <AxesSubplot:>

# %%
mask = np.triu(np.ones_like(corr, dtype=np.bool))
sns.heatmap(corr,mask=mask)
plt.show()

# %%
cardio.fcm.plot(kind = 'line', color = 'g', label = 'Fréquence Card. max ',linewidth = 1, alpha = 0.5, grid = True, linestyle = ':')
cardio.chol.plot(color = 'r',label = 'Cholésterol',linewidth = 1, alpha = 0.5, grid = True, linestyle = '-.')
plt.legend(loc='upper right')
plt.ylabel('Valeur')
plt.title('Fréquence Cardiaque Maximale - Cholésterol')
plt.show()

# %%
sns.pairplot(cardio)

# %%
pd.plotting.scatter_matrix(cardio, alpha=0.3, figsize=(14,8), diagonal='kde');

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, show, output_file
from bokeh.models import ColumnDataSource, HoverTool, Panel
from bokeh.models.widgets import Tabs
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1124">Loading BokehJS ...</span>
#     </div>

# %%
class BokehHistogram():

    def __init__(self, colors=["SteelBlue", "Tan"], height=600, width=600):
        self.colors = colors
        self.height = height
        self.width = width

    def hist_hover(self, dataframe, column, bins=30, log_scale=False, show_plot=True):
        hist, edges = np.histogram(dataframe[column], bins = bins)
        hist_df = pd.DataFrame({column: hist,
                                 "left": edges[:-1],
                                 "right": edges[1:]})
        hist_df["interval"] = ["%d to %d" % (left, right) for left, 
                               right in zip(hist_df["left"], hist_df["right"])]

        if log_scale == True:
            hist_df["log"] = np.log(hist_df[column])
            src = ColumnDataSource(hist_df)
            plot = figure(plot_height = self.height, plot_width = self.width,
                  title = "Histogramme de {}".format(column.capitalize()),
                  x_axis_label = column.capitalize(),
                  y_axis_label = "Log Count")    
            plot.quad(bottom = 0, top = "log",left = "left", 
                right = "right", source = src, fill_color = self.colors[0], 
                line_color = "black", fill_alpha = 0.7,
                hover_fill_alpha = 1.0, hover_fill_color = self.colors[1])
        else:
            src = ColumnDataSource(hist_df)
            plot = figure(plot_height = self.height, plot_width = self.width,
                  title = "Histogramme de {}".format(column.capitalize()),
                  x_axis_label = column.capitalize(),
                  y_axis_label = "Count")    
            plot.quad(bottom = 0, top = column,left = "left", 
                right = "right", source = src, fill_color = self.colors[0], 
                line_color = "black", fill_alpha = 0.7,
                hover_fill_alpha = 1.0, hover_fill_color = self.colors[1])

        hover = HoverTool(tooltips = [('Interval', '@interval'),
                                  ('Count', str("@" + column))])
        plot.add_tools(hover)

        if show_plot == True:
            show(plot)
        else:
            return plot

    def histotabs(self, dataframe, features, log_scale=False, show_plot=False):
        hists = []
        for f in features:
            h = self.hist_hover(dataframe, f, log_scale=log_scale, show_plot=show_plot)
            p = Panel(child=h, title=f.capitalize())
            hists.append(p)
        t = Tabs(tabs=hists)
        show(t)

    def filtered_histotabs(self, dataframe, feature, filter_feature, log_scale=False, show_plot=False):
        hists = []
        for col in dataframe[filter_feature].unique():
            sub_df = dataframe[dataframe[filter_feature] == col]
            histo = self.hist_hover(sub_df, feature, log_scale=log_scale, show_plot=show_plot)
            p = Panel(child = histo, title=col)
            hists.append(p)
        t = Tabs(tabs=hists)
        show(t)

# %%
h=BokehHistogram()
h.hist_hover(cardio.fillna(value=0, axis=1), 'fcm', log_scale=True)
# Out:
#   <div class="bk-root" id="9cc52357-4bdf-495e-956c-89cf8a37b519" data-root-id="3968"></div>

# %%
h.hist_hover(cardio.fillna(0, axis=1), 'age', log_scale=True)

h.histotabs(cardio.fillna(0, axis=1), ['age', 'fcm', 'chol'], log_scale=True)
# Out:
#   <div class="bk-root" id="4ec7edc1-f674-4d38-88f4-b8448ea683d6" data-root-id="4226"></div>
#   <div class="bk-root" id="f2b1e9db-226d-4710-8063-5eef8b46ba4a" data-root-id="4620"></div>
